# %% [markdown]
# # This is a sample Jupyter Notebook
#
# Below is an example of a code cell.
# Put your cursor into the cell and press Shift+Enter to execute it and select the next one, or click 'Run Cell' button.
#
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
#
# To learn more about Jupyter Notebooks in PyCharm, see [help](https://www.jetbrains.com/help/pycharm/ipython-notebook-support.html).
# For an overview of PyCharm, go to Help -> Learn IDE features or refer to [our documentation](https://www.jetbrains.com/help/pycharm/getting-started.html).

# %%
from unittest.mock import inplace

import pandas
from conda.plugins.virtual_packages import conda
from setuptools.command import install

print("hello")
# Out:
# hello

# %%
conda install
pandas
# Out:
#   Cell In[151], line 1
#     conda install
#           ^
# SyntaxError: invalid syntax

# %%
conda install pandas

# %%
import pandas as pd
s= pd.Series([1,2,3,4,5])

# %%
s

# %%
s = pd.DataFrame({"names": ["m","b","c"],"age":["10","20","30"]})

# %%
s

# %%
df = pd.read_csv("data/Combined_dataset.csv")

# %%
df

# %%
df.head()

# %%
df.tail()
# Out:
#      product_id     title                                product_description  \
# 995    13698258     KREDO  Men FORTE Silver Automatic Skeleton Analogue W...
# 996    16896006     GUESS  Women White Patterned Dial & White Straps Anal...
# 997     1708108  GIORDANO  Women Rose Gold-Toned Mirrored Analogue Watch ...
# 998    19280114  Fastrack  Men Black Brass Dial & Black Stainless Steel S...
# 999    18601682   BOLDFIT                           Purple Textured Yoga Mat
#
#      rating  ratings_count  initial_price  discount   final_price currency  \
# 995     3.5             11          11890      50.0  "₹11,890.00"      INR
# 996     5.0             22           8900      45.0   "₹8,900.00"      INR
# 997     2.8              5           7950      50.0   "₹7,950.00"      INR
# 998     4.3             17           3295      20.0   "₹2,636.00"      INR
# 999     3.8            161            699      31.0     "₹699.00"      INR
#
# ...

# %%
type(df.iloc[0])
# Out:
# pandas.Series

# %%
df.dtypes
# Out:
# product_id                  int64
# title                         str
# product_description           str
# rating                    float64
# ratings_count               int64
# initial_price               int64
# discount                  float64
# final_price                   str
# currency                      str
# images                        str
# delivery_options              str
# product_details               str
# breadcrumbs                   str
# product_specifications        str
# amount_of_stars               str
# what_customers_said           str
# seller_name                   str
# sizes                         str
# videos                        str
# seller_information            str
# variations                    str
# best_offer                    str
# more_offers                   str
# category                      str
# quantity                    int64
# total_amount                int64
# dtype: object

# %%
df.shape
# Out:
# (1000, 26)

# %%
df.columns
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category', 'quantity', 'total_amount'],
#       dtype='str')

# %%
df2=df.copy()

# %%
df2.loc[0,"rating"]=None
df2.loc[0,"final_price"]=None
df2.loc[4,"title"]=None

# %%
df2.isnull().sum()
# Out:
# product_id                  0
# title                       1
# product_description         0
# rating                      1
# ratings_count               0
# initial_price               0
# discount                  121
# final_price                 1
# currency                    0
# images                      0
# delivery_options            0
# product_details             0
# breadcrumbs                 0
# product_specifications      0
# amount_of_stars             0
# what_customers_said       573
# seller_name               301
# sizes                       0
# videos                    781
# seller_information        301
# variations                562
# best_offer                  0
# more_offers                 0
# category                    0
# quantity                    0
# total_amount                0
# dtype: int64

# %%
df2.fillna(0)
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916               0
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     0.0             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# ...

# %%
df2.dropna()
# Out:
#      product_id            title  \
# 418    18689340   Flying Machine
# 752    18241626         Roadster
# 753    18241400         Roadster
# 754    18241644         Roadster
# 755    18240570    all about you
# 756    18240582    all about you
# 757    18337610         Roadster
# 760    18241294         Roadster
# 762    18241298         Roadster
# 904    18937522  her by invictus
#
#                                    product_description  rating  ratings_count  \
# 418  Women Black Wide Leg High-Rise Light Fade Crop...     4.3             36
# 752  The  Lifestyle Co. Women Maroon & Black Ribbed...     4.5             25
# 753     Women Black & White Geometric Pullover Sweater     3.8             57
# 754     The  Lifestyle Co. Women Pink Acrylic Pullover     4.3             55
# 755             Women Navy Blue & Red Checked Pullover     4.3             53
# 756                   Women Maroon Cable Knit Pullover     4.4             39
# ...

# %%
df[["title","rating","product_description"]]
# Out:
#               title  rating                                product_description
# 0       Lino Perros     3.8                     Women Navy Blue Solid Backpack
# 1    Tommy Hilfiger     4.5                  Unisex Navy Blue Striped Backpack
# 2             Lavie     4.4                     Aries Women Pink Mini Backpack
# 3            F Gear     4.4         Unisex Navy & Grey Printed Burner Backpack
# 4         MYTRIDENT     4.7                           Men Blue Solid Bath Robe
# ..              ...     ...                                                ...
# 995           KREDO     3.5  Men FORTE Silver Automatic Skeleton Analogue W...
# 996           GUESS     5.0  Women White Patterned Dial & White Straps Anal...
# 997        GIORDANO     2.8  Women Rose Gold-Toned Mirrored Analogue Watch ...
# 998        Fastrack     4.3  Men Black Brass Dial & Black Stainless Steel S...
# 999         BOLDFIT     3.8                           Purple Textured Yoga Mat
#
# [1000 rows x 3 columns]

# %%
df[df["rating"]>3]
# Out:
#      product_id              title  \
# 0       8376765        Lino Perros
# 1       9136281     Tommy Hilfiger
# 2      17633752              Lavie
# 3       1376949             F Gear
# 4      13939916          MYTRIDENT
# ..          ...                ...
# 994     8481603  French Connection
# 995    13698258              KREDO
# 996    16896006              GUESS
# 998    19280114           Fastrack
# 999    18601682            BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.drop_duplicates()
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# ...

# %%
df["quantity"]=3
df[["title","quantity"]]
# Out:
#               title  quantity
# 0       Lino Perros         3
# 1    Tommy Hilfiger         3
# 2             Lavie         3
# 3            F Gear         3
# 4         MYTRIDENT         3
# ..              ...       ...
# 995           KREDO         3
# 996           GUESS         3
# 997        GIORDANO         3
# 998        Fastrack         3
# 999         BOLDFIT         3
#
# [1000 rows x 2 columns]

# %%
df['total_amount'] = df['initial_price'] * df['quantity']
df[['initial_price', 'quantity', 'total_amount']]
# Out:
#      initial_price  quantity  total_amount
# 0             3995         3         11985
# 1             2899         3          8697
# 2             2999         3          8997
# 3             1675         3          5025
# 4             2899         3          8697
# ..             ...       ...           ...
# 995          11890         3         35670
# 996           8900         3         26700
# 997           7950         3         23850
# 998           3295         3          9885
# 999            699         3          2097
#
# [1000 rows x 3 columns]

# %%
df.to_csv("Updated_Combined_dataset.csv", index=False)

# %% [markdown]
# - Loaded the dataset using Pandas.
# - Explored the dataset using head(), tail(), shape, columns, and data types.
# - Identified and handled missing values.
# - Selected columns and filtered rows.
# - Checked and removed duplicate records.
# - Created a derived column named total_amount.
# - Saved the cleaned dataset as a new CSV file.

# %%
df.to_csv("Updated_combined_dataset.csv", index=False)
